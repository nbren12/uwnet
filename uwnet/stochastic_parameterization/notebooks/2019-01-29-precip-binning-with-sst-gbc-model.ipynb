# %% [markdown]
# The following is based on gradient-boosting-classifier transition matrices that take the current eta, the normalized sea surface temperature, and the normalized square of the sea surface temperature as inputs.

# %%
from stochastic_parameterization.stochastic_state_model import (
    StochasticStateModel,
)
from stochastic_parameterization.utils import get_dataset
from stochastic_parameterization.examine_stochastic_state_model import plot_true_eta_vs_simulated_eta
ds = get_dataset(binning_method='precip')

# %%
# %matplotlib inline
plot_true_eta_vs_simulated_eta(ds)
