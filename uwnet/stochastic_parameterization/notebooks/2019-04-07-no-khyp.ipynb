# %% [markdown]
# Setting khype = 0 makes it so the mean precipitation decreases less over the course of a 10-day gcm run than with the khyp param. However, the zonal variance still decreases substantially over the course of the 10 days. Therefore, the hyper diffusion from SAM is not causing the zonal variance to decrease, and the current implementation of the stochastic state model does not yield a higher zonal variance than the base model with hyper diffusion.

# %% [markdown]
# In the figures below, "base model" is the non-stochastic neural network run in the gcm WITH khyp. So it is unclear whether the mean precip is higher because of the stochastic parameterization or because of the lack of khyp.

# %%
# %matplotlib inline
# %run ../compare_stochastic_model_to_base_model.py

# %% [markdown]
# Problem with getting rid of khype: the output needs to be smoothed. Below is the graph of PW at day 10 of a gcm run without any hyper diffusion:

# %%
from IPython.display import Image
Image(filename='/Users/stewart/Desktop/no_khype_pw_10_days.png')

# %% [markdown]
# Here is PW at day 10 of a gcm run with hyper diffusion:

# %%
Image(filename='/Users/stewart/Desktop/pw_day_10.png')
