# %%
from stochastic_parameterization.stochastic_state_model import (
    StochasticStateModel,
)
from stochastic_parameterization.examine_stochastic_state_model import (
    plot_true_eta_vs_simulated_eta,
)
from stochastic_parameterization.utils import get_dataset
from stochastic_parameterization.eta_heat_map import (
    plot_one_point_in_time,
    plot_tropis_heatmaps,
    plot_full_dataset_heatmaps,
    binning_quantiles,
)

# %%
ds = get_dataset(binning_method='q2_ratio')

# %%
plot_one_point_in_time(ds)

# %%
plot_full_dataset_heatmaps(ds)

# %%
plot_true_eta_vs_simulated_eta()

# %%
from stochastic_parameterization.utils import get_q2_ratio_transition_matrix
print(get_q2_ratio_transition_matrix().round(2))
# Out:
# [[0.15 0.24 0.18 0.13 0.09 0.1  0.1 ]
#  [0.09 0.24 0.34 0.16 0.06 0.05 0.06]
#  [0.02 0.08 0.44 0.39 0.03 0.02 0.02]
#  [0.02 0.03 0.05 0.65 0.15 0.06 0.03]
#  [0.07 0.06 0.05 0.24 0.32 0.18 0.09]
#  [0.12 0.11 0.08 0.15 0.21 0.2  0.14]
#  [0.15 0.17 0.11 0.13 0.13 0.15 0.14]]
