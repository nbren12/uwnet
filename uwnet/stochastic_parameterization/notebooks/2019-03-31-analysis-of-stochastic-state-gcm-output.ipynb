# %% [markdown]
# The stochastic state model is run in the gcm for 10 days and compared to a non-stochastic model with one linear model on top of the neural network. The stochastic state model provides almost no improvement towards the lack of zonal variability and decrease in precipitation that we see with the base model.
#
# However, the transitioner appears to be picking up on the decrease in variability and precipitation by increasing the transition probability towards the highest residual bin as time goes on. This indicates that by making the top bin more extreme such that a larger variation is provided may increase the effect that the stochastic state model has on the gcm.

# %%
from uwnet.stochastic_parameterization.analyze_python_gcm_data import plot_tropics_eta_distribution_over_time
from uwnet.stochastic_parameterization.compare_stochastic_model_to_base_model import (
    plot_pw_over_time,
    plot_npnn_over_time_equator,
    plot_zonal_mean_net_precip_over_time,
    plot_pw_tropics_zonal_variance_over_time,
)

# %% [markdown]
# The stochastic state model provides almost no improvement over the base model:

# %%
plot_pw_over_time()
plot_npnn_over_time_equator()
plot_zonal_mean_net_precip_over_time()
plot_pw_tropics_zonal_variance_over_time()

# %% [markdown]
# The transitioner reactes to the loss of variation by increasing the probability of the highest bin:

# %%
plot_tropics_eta_distribution_over_time()
