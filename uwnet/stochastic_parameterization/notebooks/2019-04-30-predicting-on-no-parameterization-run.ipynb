# %%
from uwnet.stochastic_parameterization.analyze_python_gcm_data import plot_nn_output_vs_true
# %matplotlib inline
plot_nn_output_vs_true()
# Out:
# Transitioner Train Score: 0.4292386487275429
#
#
# Transitioner Test Score: 0.42922600619195045
# Training residual stochastic state model
# Training eta=0...
# QT test score: 0.1661242505220523
# QT train score: 0.1894245712465749
# SLI test score: 0.13998347662990754
# SLI train score: 0.15820077976301253
# Training eta=1...
# QT test score: 0.15718918748837551
# QT train score: 0.1762650592914373
# SLI test score: 0.02579686406593948
# SLI train score: 0.0562926769242964
# Training eta=2...
# QT test score: 0.15419953221021312
# QT train score: 0.16899419845841976
# SLI test score: 0.018485570257243632
# SLI train score: 0.042114196613087206
# Training eta=3...
# QT test score: 0.16471715893308508
# QT train score: 0.16891421771386958
# SLI test score: 0.02228159629604872
# SLI train score: 0.03063499820673437
# Training eta=4...
# QT test score: 0.19362161320955307
# QT train score: 0.20465765759449758
# SLI test score: 0.0311199069635775
# SLI train score: 0.04525673874447552
# ...
