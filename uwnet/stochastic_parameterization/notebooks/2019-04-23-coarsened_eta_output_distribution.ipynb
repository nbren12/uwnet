# %% [markdown]
# The following has eta coarsened to 2x2 grid cells. Compared to the uncoarsened dataset, the distribution is closer to the true distribution.

# %%
from uwnet.stochastic_parameterization.residual_stochastic_state_model import StochasticStateModel
from uwnet.stochastic_parameterization.examine_stochastic_state_model import compare_true_to_simulated_q1_q2_distributions
dir_ = '/Users/stewart/projects/uwnet/uwnet/stochastic_parameterization/'
base_model_location = dir_ + 'full_model/1.pkl'
ds_location = dir_ + 'training.nc'
model = StochasticStateModel(eta_coarsening=2, ds_location=ds_location, base_model_location=base_model_location)
model.train()
compare_true_to_simulated_q1_q2_distributions(model, true_etas=False, only_tropics=False)
# Out:
# Transitioner Train Score: 0.3340454210218458
#
#
# Transitioner Test Score: 0.3314853432344913
# Training residual stochastic state model
# Training eta=0...
# QT test score: 0.1851699432142837
# QT train score: 0.19281434075797102
# SLI test score: 0.17444912667162857
# SLI train score: 0.1816661747445256
# Training eta=1...
# QT test score: 0.2140508257096276
# QT train score: 0.22157968602975464
# SLI test score: 0.07428308466568447
# SLI train score: 0.08372898107971853
# Training eta=2...
# QT test score: 0.2323334090686039
# QT train score: 0.22897409560969226
# SLI test score: 0.044802027729282476
# SLI train score: 0.051014477172320334
# Training eta=3...
# QT test score: 0.238850474553814
# QT train score: 0.24439801867608096
# SLI test score: 0.03492851859063277
# SLI train score: 0.03612400158442954
# Training eta=4...
# QT test score: 0.24151871155764795
# QT train score: 0.24026432910219378
# SLI test score: 0.04663158209399834
# SLI train score: 0.05210274685402054
# ...
