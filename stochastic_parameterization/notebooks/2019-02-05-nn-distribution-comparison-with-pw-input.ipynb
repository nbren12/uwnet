# %% [markdown]
# Same as "2019-2-5-nn-distribution-comparison", but with precipital water as an input to the transition matrix model in addition to the existing predictors: SST and current eta.

# %%
from stochastic_parameterization.stochastic_state_model import (
    StochasticStateModel,
)
# %matplotlib inline
from stochastic_parameterization.examine_stochastic_state_model import (
    plot_true_eta_vs_simulated_eta,
    compare_true_to_simulated_q1_q2_distributions,
)

# %% [markdown]
# The additional predictor improves the fit of the eta distribution:

# %%
plot_true_eta_vs_simulated_eta()

# %% [markdown]
# The distribution of the NN forcings is slightly better as well, but still problematic.

# %%
compare_true_to_simulated_q1_q2_distributions()
# Out:
# True QT Variance: 1.3352905742610546
# Stochastic QT Variance: 0.8566429413894935
# Base Model QT Variance: 0.7468745878009472
# True sli Variance: 7.675084487523184
# Stochastic sli Variance: 3.0302429042555565
# Base Model sli Variance: 4.441059690181341
#
#
# SLI R2 Stochastic Model: -0.6963475196113478
# SLI R2 Single Model Model: 0.37973111562936157
# QT R2 Stochastic Model: -0.22973961556819522
# QT R2 Single Model Model: 0.24607354742897614
#
#
# KS Divergence test: QT true vs single model: Ks_2sampResult(statistic=0.10049316406250008, pvalue=0.0)
# KS Divergence test: QT true vs stochastic model: Ks_2sampResult(statistic=0.12173095703125003, pvalue=0.0)
# KS Divergence test: SLI true vs single model: Ks_2sampResult(statistic=0.17499267578125002, pvalue=0.0)
# KS Divergence test: SLI true vs stochastic model: Ks_2sampResult(statistic=0.11121826171874999, pvalue=0.0)
