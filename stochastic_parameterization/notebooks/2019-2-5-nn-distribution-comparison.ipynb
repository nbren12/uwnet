# %% [markdown]
# First pass at comparing the distribution of Q1 and Q2 produced by the stochastic model to that produced by the true model. We see that the r2 is negative for the stochastic state model, and it does not produce more variance, so something is going wrong. This may be because we are binning on precip instead of Q2 ratio, or there may be an error in the code, or we may need a more aware transition model.

# %%
from stochastic_parameterization.stochastic_state_model import (
    StochasticStateModel,
)
# %matplotlib inline
from stochastic_parameterization.examine_stochastic_state_model import (
    plot_true_eta_vs_simulated_eta,
    compare_true_to_simulated_q1_q2_distributions,
)

# %%
plot_true_eta_vs_simulated_eta()

# %% [markdown]
# The model is stepped forward 50 time steps, and the q1 and q2 from the single model, the stochastic model, and the true values are computed. The comparison of these values is shown below.

# %%
compare_true_to_simulated_q1_q2_distributions()
# Out:
# True QT Variance: 1.3352905742610546
# Stochastic QT Variance: 0.6302948114173609
# Base Model QT Variance: 0.7468745878009472
# True sli Variance: 7.675084487523184
# Stochastic sli Variance: 1.7000038676644613
#
#
# Base Model sli Variance: 4.441059690181341
# SLI R2 Stochastic Model: -2.715171896793323
# SLI R2 Single Model Model: 0.37973111562936157
# QT R2 Stochastic Model: -0.8892696726030453
# QT R2 Single Model Model: 0.24607354742897614
#
#
# KS Divergence test: QT true vs single model: Ks_2sampResult(statistic=0.10049316406250008, pvalue=0.0)
# KS Divergence test: QT true vs stochastic model: Ks_2sampResult(statistic=0.12860107421875, pvalue=0.0)
# KS Divergence test: SLI true vs single model: Ks_2sampResult(statistic=0.17499267578125002, pvalue=0.0)
# KS Divergence test: SLI true vs stochastic model: Ks_2sampResult(statistic=0.10457763671874998, pvalue=0.0)
