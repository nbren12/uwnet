# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.display import Image
plt.rc('savefig', dpi=150)

# %% [markdown]
# # Figure: WMAX

# %% [markdown]
# %run instability_wmax.py
# plt.savefig("instability.png")

# %% [markdown]
# # Figure: Q1 and Q2 predictions

# %%
# %run predicted_vs_actual_q1.py
# Out:
# /Users/noah/anaconda/envs/uwnet/lib/python3.7/site-packages/torch/serialization.py:435: SourceChangeWarning: source code of class 'torch.nn.modules.container.Sequential' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /Users/noah/anaconda/envs/uwnet/lib/python3.7/site-packages/torch/serialization.py:435: SourceChangeWarning: source code of class 'uwnet.normalization.Scaler' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /Users/noah/anaconda/envs/uwnet/lib/python3.7/site-packages/torch/serialization.py:435: SourceChangeWarning: source code of class 'torch.nn.modules.container.ParameterDict' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /Users/noah/anaconda/envs/uwnet/lib/python3.7/site-packages/torch/serialization.py:435: SourceChangeWarning: source code of class 'torch.nn.modules.linear.Linear' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /Users/noah/anaconda/envs/uwnet/lib/python3.7/site-packages/torch/serialization.py:435: SourceChangeWarning: source code of class 'torch.nn.modules.activation.ReLU' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)

# %% [markdown]
# # Figure: Saliency maps

# %%
import jacobian

# %%
axs = jacobian.plot(jacobian.get_data("../../models/265/5.pkl", 32))
plt.savefig("saliency-unstable.png")

# %%
args = jacobian.get_data("../../models/268/5.pkl", 32)
jacobian.plot_with_dashes(args)
plt.savefig("saliency-stable.png")

# %% [markdown]
# # Figure: Training loss
#
# Models need to be retrained because I did not log the loss curves (although, I could extract them from the output text).

# %%
import src.sacred

# %%
df = src.sacred.get_metrics_as_pandas(270)\
 .rename(columns={'Q1/Q2': 'src'})


df.total.plot()

# %% [markdown]
# # Figure: Damping lifetime of humidity

# %%
# %run damping_coefs.py
plt.savefig("damping.pdf")

# %% [markdown]
# # Figure: RMS plots

# %%
# %run rms_weather_plots.py
plt.savefig("rms_qt.pdf")

# %% [markdown]
# # Figure: Net precipitation maps

# %%
# %run precip_maps.py
plt.savefig("precip_maps.pdf")

# %% [markdown]
# # Figure: Net precipittion hovmoller diagrams

# %%
# %run pattern_correlation.py

# %% [markdown]
# # Figure: bias

# %%
# %run bias.py

# %% [markdown]
# # Figure: bias of PW and net precip

# %%
# %run hovmoller_mean_pw_prec.py

# %% [markdown]
# # Figure: snapshots PW

# %%
# %run snapshots_pw.py

# %% [markdown]
# # Figure: spinup with multiple step loss

# %%
# %run spinup_error.py

# %% [markdown]
# # Table: Q1 and Q2 error

# %%
# %run r2_q1_q2.py
Image('./r2.png')

# %% [markdown]
# # Figure: pdf plot

# %%
# %run pdf.py

# %%
data.index.levels[0]
